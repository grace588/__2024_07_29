# %%
# 請下載日射量json資料,存檔名稱為'台灣日射量.json'
import requests
from requests.exceptions import HTTPError,ConnectionError,Timeout

try:
    url = "https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/O-A0091-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
    response = requests.get(url)
    response.raise_for_status()
    content = response.text
    #print(content)
except ConnectionError:
    print("連線伺服器發生錯誤")
except Timeout:
    print("伺服器忙碌,沒有回應")
except HTTPError:
    print("伺服器回應連線錯誤")
except Exception:
    print("不知名的錯誤")

# %%
import io
import json
from pprint import pprint
file = io.StringIO(content)
#print(type(file))
pprint(json.load(file))
# Out:
# {'cwaopendata': {'@xmlns': 'urn:cwa:gov:tw:cwacommon:0.1',
#                  'dataid': 'O-A0091-001',
#                  'dataset': {'Station': [{'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.135130',
#                                                                        'StationLongitude': '121.732265'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.133314',
#                                                                        'StationLongitude': '121.740475'}],
#                                                       'StationAltitude': '26.7'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466940',
#                                           'StationName': '基隆',
#                                           'WeatherElement': {'SolarRadiation': '14.89'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.166689',
#                                                                        'StationLongitude': '121.440690'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.164889',
#                                                                        'StationLongitude': '121.448906'}],
#                                                       'StationAltitude': '19.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466900',
#                                           'StationName': '淡水',
#                                           'WeatherElement': {'SolarRadiation': '14.98'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.961111',
#                                                                        'StationLongitude': '121.516111'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.959328',
#                                                                        'StationLongitude': '121.524330'}],
#                                                       'StationAltitude': '24.1'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466881',
#                                           'StationName': '新北',
#                                           'WeatherElement': {'SolarRadiation': '12.84'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.163883',
#                                                                        'StationLongitude': '121.536332'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.162078',
#                                                                        'StationLongitude': '121.544547'}],
#                                                       'StationAltitude': '607.1'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466930',
#                                           'StationName': '陽明山',
#                                           'WeatherElement': {'SolarRadiation': '14.80'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.184391',
#                                                                        'StationLongitude': '121.521515'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.182586',
#                                                                        'StationLongitude': '121.529731'}],
#                                                       'StationAltitude': '832.6'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466910',
#                                           'StationName': '鞍部',
#                                           'WeatherElement': {'SolarRadiation': '13.45'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.829629',
#                                                                        'StationLongitude': '121.006019'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.827853',
#                                                                        'StationLongitude': '121.014219'}],
#                                                       'StationAltitude': '26.9'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467571',
#                                           'StationName': '新竹',
#                                           'WeatherElement': {'SolarRadiation': '10.76'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.147495',
#                                                                        'StationLongitude': '120.675914'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.145736',
#                                                                        'StationLongitude': '120.684075'}],
#                                                       'StationAltitude': '84.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467490',
#                                           'StationName': '臺中',
#                                           'WeatherElement': {'SolarRadiation': '7.39'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.567203',
#                                                                        'StationLongitude': '119.554957'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.565503',
#                                                                        'StationLongitude': '119.563094'}],
#                                                       'StationAltitude': '10.7'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467350',
#                                           'StationName': '澎湖',
#                                           'WeatherElement': {'SolarRadiation': '12.68'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.883096',
#                                                                        'StationLongitude': '120.899909'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.881325',
#                                                                        'StationLongitude': '120.908050'}],
#                                                       'StationAltitude': '1014.8'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467650',
#                                           'StationName': '日月潭',
#                                           'WeatherElement': {'SolarRadiation': '6.02'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.509974',
#                                                                        'StationLongitude': '120.805123'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.508208',
#                                                                        'StationLongitude': '120.813242'}],
#                                                       'StationAltitude': '2413.4'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467530',
#                                           'StationName': '阿里山',
#                                           'WeatherElement': {'SolarRadiation': '6.48'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.489387',
#                                                                        'StationLongitude': '120.951406'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.487614',
#                                                                        'StationLongitude': '120.959522'}],
#                                                       'StationAltitude': '3844.8'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467550',
#                                           'StationName': '玉山',
#                                           'WeatherElement': {'SolarRadiation': '8.96'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.497671',
#                                                                        'StationLongitude': '120.424783'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.495925',
#                                                                        'StationLongitude': '120.432906'}],
#                                                       'StationAltitude': '26.9'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467480',
#                                           'StationName': '嘉義',
#                                           'WeatherElement': {'SolarRadiation': '10.11'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.994974',
#                                                                        'StationLongitude': '120.196676'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.993239',
#                                                                        'StationLongitude': '120.204772'}],
#                                                       'StationAltitude': '40.8'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467410',
#                                           'StationName': '臺南',
#                                           'WeatherElement': {'SolarRadiation': '8.49'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.732202',
#                                                                        'StationLongitude': '120.304461'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.730432',
#                                                                        'StationLongitude': '120.312516'}],
#                                                       'StationAltitude': '11.8'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467441',
#                                           'StationName': '高雄',
#                                           'WeatherElement': {'SolarRadiation': '7.31'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.005659',
#                                                                        'StationLongitude': '120.738307'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.003897',
#                                                                        'StationLongitude': '120.746339'}],
#                                                       'StationAltitude': '22.3'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467590',
#                                           'StationName': '恆春',
#                                           'WeatherElement': {'SolarRadiation': '8.24'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.765792',
#                                                                        'StationLongitude': '121.748343'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.763975',
#                                                                        'StationLongitude': '121.756528'}],
#                                                       'StationAltitude': '7.4'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467080',
#                                           'StationName': '宜蘭',
#                                           'WeatherElement': {'SolarRadiation': '15.37'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.976936',
#                                                                        'StationLongitude': '121.605138'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.975128',
#                                                                        'StationLongitude': '121.613275'}],
#                                                       'StationAltitude': '16.1'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466990',
#                                           'StationName': '花蓮',
#                                           'WeatherElement': {'SolarRadiation': '13.26'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.099281',
#                                                                        'StationLongitude': '121.365342'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.097486',
#                                                                        'StationLongitude': '121.373428'}],
#                                                       'StationAltitude': '33.3'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467610',
#                                           'StationName': '成功',
#                                           'WeatherElement': {'SolarRadiation': '6.61'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.753994',
#                                                                        'StationLongitude': '121.146517'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.752211',
#                                                                        'StationLongitude': '121.154586'}],
#                                                       'StationAltitude': '9.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467660',
#                                           'StationName': '臺東',
#                                           'WeatherElement': {'SolarRadiation': '4.91'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.357445',
#                                                                        'StationLongitude': '120.895740'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.355675',
#                                                                        'StationLongitude': '120.903789'}],
#                                                       'StationAltitude': '8.1'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467540',
#                                           'StationName': '大武',
#                                           'WeatherElement': {'SolarRadiation': '8.98'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '22.038771',
#                                                                        'StationLongitude': '121.550317'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '22.036969',
#                                                                        'StationLongitude': '121.558339'}],
#                                                       'StationAltitude': '324.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467620',
#                                           'StationName': '蘭嶼',
#                                           'WeatherElement': {'SolarRadiation': '7.01'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.629811',
#                                                                        'StationLongitude': '122.071506'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.627975',
#                                                                        'StationLongitude': '122.079744'}],
#                                                       'StationAltitude': '99.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466950',
#                                           'StationName': '彭佳嶼',
#                                           'WeatherElement': {'SolarRadiation': '-99'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.258657',
#                                                                        'StationLongitude': '119.659350'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.256950',
#                                                                        'StationLongitude': '119.667467'}],
#                                                       'StationAltitude': '44.5'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467300',
#                                           'StationName': '東吉島',
#                                           'WeatherElement': {'SolarRadiation': '12.62'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '10.371770',
#                                                                        'StationLongitude': '114.356682'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '10.370203',
#                                                                        'StationLongitude': '114.364286'}],
#                                                       'StationAltitude': '4.5'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '469020',
#                                           'StationName': '南沙島',
#                                           'WeatherElement': {'SolarRadiation': '10.87'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '20.702420',
#                                                                        'StationLongitude': '116.722007'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '20.700856',
#                                                                        'StationLongitude': '116.730000'}],
#                                                       'StationAltitude': '4.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '468100',
#                                           'StationName': '東沙島',
#                                           'WeatherElement': {'SolarRadiation': '13.53'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.040122',
#                                                                        'StationLongitude': '120.228602'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.038386',
#                                                                        'StationLongitude': '120.236700'}],
#                                                       'StationAltitude': '8.1'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467420',
#                                           'StationName': '永康',
#                                           'WeatherElement': {'SolarRadiation': '9.24'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.039410',
#                                                                        'StationLongitude': '121.506676'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.037658',
#                                                                        'StationLongitude': '121.514853'}],
#                                                       'StationAltitude': '6.3'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '466920',
#                                           'StationName': '臺北',
#                                           'WeatherElement': {'SolarRadiation': '14.94'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.408935',
#                                                                        'StationLongitude': '118.281080'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.407306',
#                                                                        'StationLongitude': '118.289281'}],
#                                                       'StationAltitude': '48.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467110',
#                                           'StationName': '金門',
#                                           'WeatherElement': {'SolarRadiation': '9.08'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '26.170981',
#                                                                        'StationLongitude': '119.915113'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '26.169269',
#                                                                        'StationLongitude': '119.923419'}],
#                                                       'StationAltitude': '97.8'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467990',
#                                           'StationName': '馬祖',
#                                           'WeatherElement': {'SolarRadiation': '13.98'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '25.008503',
#                                                                        'StationLongitude': '121.039267'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '25.006744',
#                                                                        'StationLongitude': '121.047486'}],
#                                                       'StationAltitude': '20.6'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467050',
#                                           'StationName': '新屋',
#                                           'WeatherElement': {'SolarRadiation': '11.69'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.875560',
#                                                                        'StationLongitude': '120.573150'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.873802',
#                                                                        'StationLongitude': '120.581287'}],
#                                                       'StationAltitude': '42.2'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467270',
#                                           'StationName': '田中',
#                                           'WeatherElement': {'SolarRadiation': '8.37'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '24.650318',
#                                                                        'StationLongitude': '120.823641'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '24.648563',
#                                                                        'StationLongitude': '120.831834'}],
#                                                       'StationAltitude': '30.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '467280',
#                                           'StationName': '後龍',
#                                           'WeatherElement': {'SolarRadiation': '13.57'}},
#                                          {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'TWD67',
#                                                                        'StationLatitude': '23.980611',
#                                                                        'StationLongitude': '121.131497'},
#                                                                       {'CoordinateFormat': 'decimal '
#                                                                                            'degrees',
#                                                                        'CoordinateName': 'WGS84',
#                                                                        'StationLatitude': '23.978875',
#                                                                        'StationLongitude': '121.139639'}],
#                                                       'StationAltitude': '1000.0'},
#                                           'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#                                           'StationId': '42HA10',
#                                           'StationName': '萬大發電廠',
#                                           'WeatherElement': {'SolarRadiation': '15.72'}}]},
#                  'identifier': 'bc67e1ec-0e8b-4e08-b05c-f8677bfde119',
#                  'msgType': 'Issue',
#                  'scope': 'Public',
#                  'sender': 'od@cwa.gov.tw',
#                  'sent': '2024-09-05T12:42:20+08:00',
#                  'status': 'Actual'}}

# %%
import io
import json
from pprint import pprint
file =io.StringIO(content)
#print(type(file))
content = json.load(file)

# %%
date:str = content['cwaopendata']['sent']

# %%
stationn:list

# %%
# 請下載日射量json資料,存檔名稱為'台灣日射量.json'
import requests
from requests.exceptions import HTTPError,ConnectionError,Timeout

try:
    url = "https://opendata.cwa.gov.tw/fileapi/v1/opendataapi/O-A0091-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
    response = requests.get(url)
    response.raise_for_status()
    content = response.text
    #print(content)
except ConnectionError:
    print("連線伺服器發生錯誤")
except Timeout:
    print("伺服器忙碌,沒有回應")
except HTTPError:
    print("伺服器回應連線錯誤")
except Exception:
    print("不知名的錯誤")

# %%
import io
import json
from pprint import pprint
file = io.StringIO(content)
#print(type(file))
contents = json.load(file)

# %%
date:str = contents['cwaopendata']['sent']

# %%
stations:list = contents['cwaopendata']['dataset']['Station']
pprint(stations)
# Out:
# [{'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.135130',
#                                'StationLongitude': '121.732265'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.133314',
#                                'StationLongitude': '121.740475'}],
#               'StationAltitude': '26.7'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466940',
#   'StationName': '基隆',
#   'WeatherElement': {'SolarRadiation': '14.89'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.166689',
#                                'StationLongitude': '121.440690'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.164889',
#                                'StationLongitude': '121.448906'}],
#               'StationAltitude': '19.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466900',
#   'StationName': '淡水',
#   'WeatherElement': {'SolarRadiation': '14.98'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.961111',
#                                'StationLongitude': '121.516111'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.959328',
#                                'StationLongitude': '121.524330'}],
#               'StationAltitude': '24.1'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466881',
#   'StationName': '新北',
#   'WeatherElement': {'SolarRadiation': '12.84'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.163883',
#                                'StationLongitude': '121.536332'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.162078',
#                                'StationLongitude': '121.544547'}],
#               'StationAltitude': '607.1'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466930',
#   'StationName': '陽明山',
#   'WeatherElement': {'SolarRadiation': '14.80'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.184391',
#                                'StationLongitude': '121.521515'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.182586',
#                                'StationLongitude': '121.529731'}],
#               'StationAltitude': '832.6'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466910',
#   'StationName': '鞍部',
#   'WeatherElement': {'SolarRadiation': '13.45'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.829629',
#                                'StationLongitude': '121.006019'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.827853',
#                                'StationLongitude': '121.014219'}],
#               'StationAltitude': '26.9'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467571',
#   'StationName': '新竹',
#   'WeatherElement': {'SolarRadiation': '10.76'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.147495',
#                                'StationLongitude': '120.675914'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.145736',
#                                'StationLongitude': '120.684075'}],
#               'StationAltitude': '84.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467490',
#   'StationName': '臺中',
#   'WeatherElement': {'SolarRadiation': '7.39'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.567203',
#                                'StationLongitude': '119.554957'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.565503',
#                                'StationLongitude': '119.563094'}],
#               'StationAltitude': '10.7'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467350',
#   'StationName': '澎湖',
#   'WeatherElement': {'SolarRadiation': '12.68'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.883096',
#                                'StationLongitude': '120.899909'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.881325',
#                                'StationLongitude': '120.908050'}],
#               'StationAltitude': '1014.8'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467650',
#   'StationName': '日月潭',
#   'WeatherElement': {'SolarRadiation': '6.02'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.509974',
#                                'StationLongitude': '120.805123'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.508208',
#                                'StationLongitude': '120.813242'}],
#               'StationAltitude': '2413.4'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467530',
#   'StationName': '阿里山',
#   'WeatherElement': {'SolarRadiation': '6.48'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.489387',
#                                'StationLongitude': '120.951406'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.487614',
#                                'StationLongitude': '120.959522'}],
#               'StationAltitude': '3844.8'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467550',
#   'StationName': '玉山',
#   'WeatherElement': {'SolarRadiation': '8.96'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.497671',
#                                'StationLongitude': '120.424783'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.495925',
#                                'StationLongitude': '120.432906'}],
#               'StationAltitude': '26.9'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467480',
#   'StationName': '嘉義',
#   'WeatherElement': {'SolarRadiation': '10.11'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.994974',
#                                'StationLongitude': '120.196676'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.993239',
#                                'StationLongitude': '120.204772'}],
#               'StationAltitude': '40.8'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467410',
#   'StationName': '臺南',
#   'WeatherElement': {'SolarRadiation': '8.49'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.732202',
#                                'StationLongitude': '120.304461'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.730432',
#                                'StationLongitude': '120.312516'}],
#               'StationAltitude': '11.8'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467441',
#   'StationName': '高雄',
#   'WeatherElement': {'SolarRadiation': '7.31'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.005659',
#                                'StationLongitude': '120.738307'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.003897',
#                                'StationLongitude': '120.746339'}],
#               'StationAltitude': '22.3'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467590',
#   'StationName': '恆春',
#   'WeatherElement': {'SolarRadiation': '8.24'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.765792',
#                                'StationLongitude': '121.748343'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.763975',
#                                'StationLongitude': '121.756528'}],
#               'StationAltitude': '7.4'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467080',
#   'StationName': '宜蘭',
#   'WeatherElement': {'SolarRadiation': '15.37'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.976936',
#                                'StationLongitude': '121.605138'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.975128',
#                                'StationLongitude': '121.613275'}],
#               'StationAltitude': '16.1'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466990',
#   'StationName': '花蓮',
#   'WeatherElement': {'SolarRadiation': '13.26'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.099281',
#                                'StationLongitude': '121.365342'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.097486',
#                                'StationLongitude': '121.373428'}],
#               'StationAltitude': '33.3'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467610',
#   'StationName': '成功',
#   'WeatherElement': {'SolarRadiation': '6.61'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.753994',
#                                'StationLongitude': '121.146517'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.752211',
#                                'StationLongitude': '121.154586'}],
#               'StationAltitude': '9.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467660',
#   'StationName': '臺東',
#   'WeatherElement': {'SolarRadiation': '4.91'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.357445',
#                                'StationLongitude': '120.895740'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.355675',
#                                'StationLongitude': '120.903789'}],
#               'StationAltitude': '8.1'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467540',
#   'StationName': '大武',
#   'WeatherElement': {'SolarRadiation': '8.98'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '22.038771',
#                                'StationLongitude': '121.550317'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '22.036969',
#                                'StationLongitude': '121.558339'}],
#               'StationAltitude': '324.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467620',
#   'StationName': '蘭嶼',
#   'WeatherElement': {'SolarRadiation': '7.01'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.629811',
#                                'StationLongitude': '122.071506'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.627975',
#                                'StationLongitude': '122.079744'}],
#               'StationAltitude': '99.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466950',
#   'StationName': '彭佳嶼',
#   'WeatherElement': {'SolarRadiation': '-99'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.258657',
#                                'StationLongitude': '119.659350'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.256950',
#                                'StationLongitude': '119.667467'}],
#               'StationAltitude': '44.5'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467300',
#   'StationName': '東吉島',
#   'WeatherElement': {'SolarRadiation': '12.62'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '10.371770',
#                                'StationLongitude': '114.356682'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '10.370203',
#                                'StationLongitude': '114.364286'}],
#               'StationAltitude': '4.5'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '469020',
#   'StationName': '南沙島',
#   'WeatherElement': {'SolarRadiation': '10.87'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '20.702420',
#                                'StationLongitude': '116.722007'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '20.700856',
#                                'StationLongitude': '116.730000'}],
#               'StationAltitude': '4.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '468100',
#   'StationName': '東沙島',
#   'WeatherElement': {'SolarRadiation': '13.53'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.040122',
#                                'StationLongitude': '120.228602'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.038386',
#                                'StationLongitude': '120.236700'}],
#               'StationAltitude': '8.1'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467420',
#   'StationName': '永康',
#   'WeatherElement': {'SolarRadiation': '9.24'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.039410',
#                                'StationLongitude': '121.506676'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.037658',
#                                'StationLongitude': '121.514853'}],
#               'StationAltitude': '6.3'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '466920',
#   'StationName': '臺北',
#   'WeatherElement': {'SolarRadiation': '14.94'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.408935',
#                                'StationLongitude': '118.281080'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.407306',
#                                'StationLongitude': '118.289281'}],
#               'StationAltitude': '48.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467110',
#   'StationName': '金門',
#   'WeatherElement': {'SolarRadiation': '9.08'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '26.170981',
#                                'StationLongitude': '119.915113'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '26.169269',
#                                'StationLongitude': '119.923419'}],
#               'StationAltitude': '97.8'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467990',
#   'StationName': '馬祖',
#   'WeatherElement': {'SolarRadiation': '13.98'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '25.008503',
#                                'StationLongitude': '121.039267'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '25.006744',
#                                'StationLongitude': '121.047486'}],
#               'StationAltitude': '20.6'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467050',
#   'StationName': '新屋',
#   'WeatherElement': {'SolarRadiation': '11.69'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.875560',
#                                'StationLongitude': '120.573150'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.873802',
#                                'StationLongitude': '120.581287'}],
#               'StationAltitude': '42.2'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467270',
#   'StationName': '田中',
#   'WeatherElement': {'SolarRadiation': '8.37'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '24.650318',
#                                'StationLongitude': '120.823641'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '24.648563',
#                                'StationLongitude': '120.831834'}],
#               'StationAltitude': '30.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '467280',
#   'StationName': '後龍',
#   'WeatherElement': {'SolarRadiation': '13.57'}},
#  {'GeoInfo': {'Coordinates': [{'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'TWD67',
#                                'StationLatitude': '23.980611',
#                                'StationLongitude': '121.131497'},
#                               {'CoordinateFormat': 'decimal degrees',
#                                'CoordinateName': 'WGS84',
#                                'StationLatitude': '23.978875',
#                                'StationLongitude': '121.139639'}],
#               'StationAltitude': '1000.0'},
#   'ObsTime': {'DateTime': '2024-09-05T12:30:00+08:00'},
#   'StationId': '42HA10',
#   'StationName': '萬大發電廠',
#   'WeatherElement': {'SolarRadiation': '15.72'}}]

# %%
#for station in stations:
#    name:str = station['StationName']
#    weather:str = station['WeatherElement']['SolarRadiation']
#    print(name,weather)
#    print("====================")

# %%
class Station():
    def __init__(self,name:str,weather:float):
        self.name = name
        self.weather = weather

stations1:list = []
for station in stations:
    name:str = station['StationName']
    weather:str = station['WeatherElement']['SolarRadiation']
    station:Station = Station(name,float(weather))
    stations1.append(station)

stations1
# Out:
# [<__main__.Station at 0x7898b705e350>,
#  <__main__.Station at 0x7898b7079fd0>,
#  <__main__.Station at 0x7898b7079c50>,
#  <__main__.Station at 0x7898b707a150>,
#  <__main__.Station at 0x7898b7079850>,
#  <__main__.Station at 0x7898b707a090>,
#  <__main__.Station at 0x7898b707a0d0>,
#  <__main__.Station at 0x7898b707a390>,
#  <__main__.Station at 0x7898b707a290>,
#  <__main__.Station at 0x7898b7079f50>,
#  <__main__.Station at 0x7898b707a490>,
#  <__main__.Station at 0x7898b707a4d0>,
#  <__main__.Station at 0x7898b707a510>,
#  <__main__.Station at 0x7898b707a550>,
#  <__main__.Station at 0x7898b707a590>,
#  <__main__.Station at 0x7898b707a5d0>,
#  <__main__.Station at 0x7898b707a3d0>,
#  <__main__.Station at 0x7898b707a2d0>,
#  <__main__.Station at 0x7898b707a310>,
#  <__main__.Station at 0x7898b707a350>,
#  <__main__.Station at 0x7898b707a410>,
#  <__main__.Station at 0x7898b707a450>,
#  <__main__.Station at 0x7898b707a610>,
#  <__main__.Station at 0x7898b707a710>,
#  <__main__.Station at 0x7898b707a850>,
#  <__main__.Station at 0x7898b707a890>,
#  <__main__.Station at 0x7898b707a8d0>,
#  <__main__.Station at 0x7898b707a910>,
#  <__main__.Station at 0x7898b707a950>,
#  <__main__.Station at 0x7898b707a750>,
#  <__main__.Station at 0x7898b707a650>,
#  <__main__.Station at 0x7898b707a690>,
#  <__main__.Station at 0x7898b707a6d0>]
